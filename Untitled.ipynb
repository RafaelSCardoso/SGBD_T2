# %% [markdown]
# ## Análise Exploratória

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import scipy.stats as stats

# %%
df = pd.read_csv('./Dataset/fertility_Diagnosis.csv')
df #.head(15)
# Out:
#     Season  Age(18-36)  Childish-desease  Trauma  Surgical-Intervation  \
# 0    -0.33        0.69                 0       1                     1
# 1    -0.33        0.94                 1       0                     1
# 2    -0.33        0.50                 1       0                     0
# 3    -0.33        0.75                 0       1                     1
# 4    -0.33        0.67                 1       1                     0
# ..     ...         ...               ...     ...                   ...
# 95   -1.00        0.67                 1       0                     0
# 96   -1.00        0.61                 1       0                     0
# 97   -1.00        0.67                 1       1                     1
# 98   -1.00        0.64                 1       0                     1
# 99   -1.00        0.69                 0       1                     1
#
#     Hight-fever-Last-Year  alchohol-consuption  smoking-habit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Season                 100 non-null    float64
#  1   Age(18-36)             100 non-null    float64
#  2   Childish-desease       100 non-null    int64
#  3   Trauma                 100 non-null    int64
#  4   Surgical-Intervation   100 non-null    int64
#  5   Hight-fever-Last-Year  100 non-null    int64
#  6   alchohol-consuption    100 non-null    float64
#  7   smoking-habit          100 non-null    int64
#  8   hours-spend-sitting    100 non-null    float64
#  9   diagnosis              100 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 7.9+ KB

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.plot(x='Age(18-36)', y='alchohol-consuption', kind='scatter')
plt.show()

# %%
feature_names = ['Season','Age(18-36)','Childish-desease','Trauma','Surgical-Intervation','Hight-fever-Last-Year','alchohol-consuption','smoking-habit','hours-spend-sitting','diagnosis']

# %%
pd.plotting.scatter_matrix(df[feature_names],figsize=(20, 20))
plt.show()

# %%
num_feature_names = ['Age(18-36)','Hight-fever-Last-Year','alchohol-consuption','hours-spend-sitting']

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# Como valores já vieram pré calculados, não será nessassario parrar pela etapa de normalização de dados

# %%
from sklearn.model_selection import train_test_split
df_treino, df_teste = train_test_split(df, test_size=0.2, random_state=42)
df_treino_labels = df_treino['diagnosis'].copy()
df_treino        = df_treino.drop(columns='diagnosis')
df_treino.head()
# Out:
#     Season  Age(18-36)  Childish-desease  Trauma  Surgical-Intervation  \
# 55   -0.33        0.58                 1       0                     1
# 88   -0.33        0.83                 1       1                     1
# 26    1.00        0.67                 1       0                     1
# 42   -1.00        0.58                 1       0                     1
# 69   -0.33        0.50                 1       0                     1
#
#     Hight-fever-Last-Year  alchohol-consuption  smoking-habit  \
# 55                      0                  0.8              1
# 88                      0                  1.0             -1
# 26                      0                  0.6             -1
# 42                     -1                  0.8              1
# 69                     -1                  0.8             -1
#
#     hours-spend-sitting
# 55                 0.19
# 88                 0.31
# 26                 0.38
# 42                 0.50
# 69                 0.50
