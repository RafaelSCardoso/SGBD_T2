# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import scipy.stats as stats

# %%
df = pd.read_csv('./Dataset/fertility_Diagnosis.csv')
df #.head(15)
# Out:
#     Season   Age  Childish-desease  Trauma  Surgical-Intervation  \
# 0    -0.33  0.69                 0       1                     1
# 1    -0.33  0.94                 1       0                     1
# 2    -0.33  0.50                 1       0                     0
# 3    -0.33  0.75                 0       1                     1
# 4    -0.33  0.67                 1       1                     0
# ..     ...   ...               ...     ...                   ...
# 95   -1.00  0.67                 1       0                     0
# 96   -1.00  0.61                 1       0                     0
# 97   -1.00  0.67                 1       1                     1
# 98   -1.00  0.64                 1       0                     1
# 99   -1.00  0.69                 0       1                     1
#
#     Hight-fever-Last-Year  alchohol-consuption  smoking-habit  \
# 0                       0                  0.8              0
# 1                       0                  0.8              1
# 2                       0                  1.0             -1
# 3                       0                  1.0             -1
# 4                       0                  0.8             -1
# ..                    ...                  ...            ...
# 95                      0                  1.0             -1
# 96                      0                  0.8              0
# 97                      0                  1.0             -1
# 98                      0                  1.0              0
# 99                      0                  0.6             -1
#
#     hours-spend-sitting diagnosis
# 0                  0.88         N
# 1                  0.31         O
# 2                  0.50         N
# 3                  0.38         N
# 4                  0.50         O
# ..                  ...       ...
# 95                 0.50         N
# 96                 0.50         N
# 97                 0.31         N
# 98                 0.19         N
# 99                 0.19         N
#
# [100 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Season                 100 non-null    float64
#  1   Age                    100 non-null    float64
#  2   Childish-desease       100 non-null    int64
#  3   Trauma                 100 non-null    int64
#  4   Surgical-Intervation   100 non-null    int64
#  5   Hight-fever-Last-Year  100 non-null    int64
#  6   alchohol-consuption    100 non-null    float64
#  7   smoking-habit          100 non-null    int64
#  8   hours-spend-sitting    100 non-null    float64
#  9   diagnosis              100 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 7.9+ KB

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.plot(x='Age', y='alchohol-consuption', kind='scatter')
plt.show()

# %%
feature_names = ['Season','Age','Childish-desease','Trauma','Surgical-Intervation','Hight-fever-Last-Year','alchohol-consuption','smoking-habit','hours-spend-sitting','diagnosis']

# %%
pd.plotting.scatter_matrix(df[feature_names],figsize=(20, 20))
plt.show()

# %%
num_feature_names = ['Age','Hight-fever-Last-Year','alchohol-consuption','hours-spend-sitting']

# %%
corr = np.corrcoef(df[num_feature_names],rowvar=False)
corr
# Out:
# array([[ 1.00000000e+00,  1.20284335e-01, -2.47940181e-01,
#         -4.42451951e-01],
#        [ 1.20284335e-01,  1.00000000e+00, -8.30705194e-04,
#         -1.51091430e-01],
#        [-2.47940181e-01, -8.30705194e-04,  1.00000000e+00,
#          1.11371489e-01],
#        [-4.42451951e-01, -1.51091430e-01,  1.11371489e-01,
#          1.00000000e+00]])

# %%
dfcorr = pd.DataFrame(corr,index=num_feature_names,columns=num_feature_names)
dfcorr
# Out:
#                             Age  Hight-fever-Last-Year  alchohol-consuption  \
# Age                    1.000000               0.120284            -0.247940
# Hight-fever-Last-Year  0.120284               1.000000            -0.000831
# alchohol-consuption   -0.247940              -0.000831             1.000000
# hours-spend-sitting   -0.442452              -0.151091             0.111371
#
#                        hours-spend-sitting
# Age                              -0.442452
# Hight-fever-Last-Year            -0.151091
# alchohol-consuption               0.111371
# hours-spend-sitting               1.000000

# %%
dfcorr.to_csv('correlmat.csv',sep=';',decimal=',')
